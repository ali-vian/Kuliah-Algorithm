# %% [markdown]
# # 1	Konsep Seleksi dan Iterasi
# Tulis ringkasan atau penjelasan hal-hal berikut, dengan kata-kata kalian sendiri :
# 1.	Terdapat tiga syntax percabangan di dalam Python, yaitu if, if else, dan if elif .. else. Jelaskan perbedaan ketiganya, dan tuliskan contoh code masing-masing syntax.
# 2.	Terdapat dua syntax perulangan di dalam Python, yaitu for dan while. Jelaskan perbedaan keduanya, dan tuliskan contoh code masing-masing syntax.

# %% [markdown]
# ## Jawaban
# 1. - if adalah syntax dalam percabanagn yang berfungsi sebagai awalan dari sebuah percabangan, jika tidak di awalai dengan if maka syntax akan error. Pada sebuah if terdapat kondisi jika bernilai benar maka akan di eksekusi tanpa mengeksekusi lainnya dibawahnya,dan apabila salah tidak akan di eksekusi terus lanjut ke lainnya.
# contoh:<br>
# a=3
# If a<3
#  - elif adalah gabungan dari else dan if yang biasanya terletak di antara else dan if. elif ini bisa digunakan lebih dari satu sesuai dengan keiginan kita. Pada sebuah elif terdapat kondisi jika bernilai benar maka akan di eksekusi tanpa mengeksekusi lainnya dibawahnya,dan apabila salah tidak akan di eksekusi terus lanjut ke lainnya.
# contoh:
# elif a=3:
#     print("a")
#  - else adalah syntax dalam percabangan yang berfungsi sebagai akhiran dari sebuah percabangan, apabila if dan elif di atasnya salah maka otomatis else akan di eksekusi. Dalam else ini tidak ada  statment jadi apapun yang salah di elif dan if akan di eksekusi di else.
# contoh:
# else:
#     print(i)
# 2. - for adalah syntax perulangan dalam phyton yang melakukan perulangan berdasarkan nilai yang kita tentukan. Di dalam syntax for kita bisa menentukan nilai awal, nilai akhir ,dan jarak antar angka.
# contoh:
# for i in range(1,10,2):
#     print(i)
#    - while adalah syntax perulangan dalam phyton, selama ekspresi while benar maka akan akan terus mengeksekusi perulangan. oleh karena itu kita harus membuat stopping condition.
# a=1
# while a<=10:
#     print(a)
#     a+=1

# %% [markdown]
# # 2	Implementasi
# ## 2.1	Bilangan Prima
# Buatlah flowchart (tidak harus menggunakan flogorithm) dari penentuan apakah suatu bilangan (inputan dari user) adalah bilangan prima. Implementasikan flowchart yang sudah dibuat (bukan generate dari flowgorithm) dengan menggunakan bahasa Python, sehingga menghasilkan output seperti contoh-contoh yang terdapat pada Gambar 1.
# ![image.png](attachment:image.png)
#
# 	(a)	(b)
#  ![image-2.png](attachment:image-2.png)
# 	(c)	(d)
#  ![image-3.png](attachment:image-3.png)
# 	(e)	(f)
# Gambar 1: Penentuan Bilangan Prima

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
num=int(input("masukkan bilangan prima = "))
faktor=0
for i in range(1,num+1):
    if num%i==0:
        faktor+=1
if faktor==2:
    print(num," adalah bilangan prima")
else:
    print(num," bukan prima, memiliki jumlah faktor pembagi ",faktor)
# Out:
# masukkan bilangan prima = 13
# 13  adalah bilangan prima

# %% [markdown]
# ## 2.2	Segitiga siku-siku
# Buatlah code untuk menentukan apakah suatu segitiga (diketahui adalah panjang sisi dari segita), merupakan suatu segitiga siku-siku, dengan ketentuan sebagai berikut :
# 1.	Terdapat tiga inputan, yaitu sisi-sisi segitiga (sisi pertama, sisi kedua, dan sisi ketiga)
# 2.	Segitiga siku-siku merupakan segitiga dimana kuadrat sisi miring merupakan penjumlahan dari kuadratdari masing-masing sisi siku-siku, yaitu c2 = a2 +b2 (c adalah sisi miring, a dan b merupakan sisi sikusiku). Contoh ilustrasi segitiga siku-siku ini dapat dilihat pada Gambar 2 3. Contoh inputan dan Output dari code ini dapat dilihat pada Gambar 3
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)
# ![image-3.png](attachment:image-3.png)
# ![image-4.png](attachment:image-4.png)
# ![image-5.png](attachment:image-5.png)
# ![image-6.png](attachment:image-6.png)

# %%
a=int(input("Panjang sisi pertama dari segitiga ="))
b=int(input("Panjang sisi kedua dari segitiga ="))
c=int(input("Panjang sisi ketiga dari segitiga ="))
if a>b and a>c:
    sisiMiring=a
    sikuSiku1=b
    sikuSiku2=c
elif b>c:
    sisiMiring=b
    sikuSiku1=a
    sikuSiku2=c
else:
    sisiMiring=c
    sikuSiku1=a
    sikuSiku2=b
if sisiMiring**2==sikuSiku1**2+sikuSiku2**2:
    print("Segitiga siku-siku dengan sisi siku-siku adalah ",sikuSiku1," dan ",sikuSiku2," serta sisi miring adalah ",sisiMiring)
else:
    print("Sisi { ",a," , ",b," , ",c," } Bukan segitiga siku-siku")
# Out:
# Panjang sisi pertama dari segitiga =6
# Panjang sisi kedua dari segitiga =7
# Panjang sisi ketiga dari segitiga =9
# Sisi {  6  ,  7  ,  9  } Bukan segitiga siku-siku

# %% [markdown]
# ## 2.3	Iterasi di dalam Iterasi
# Buatlah code untuk menampilkan penomoran daftar isi, seperti contoh pada 4. Dengan inputan dari user berupa jumlah bab dan sub bab dalam setiap bab. [Hint : Buatlah iterasi di dalam iterasi]

# %%
bab=int(input("Masukkan jumlah bab = "))
subBab=int(input("Masukkan jumlah sub bab di setiap bab = "))
for a in range(1,bab+1):
    print(a,".")
    for b in range(1,subBab+1):
        print("   ",a," . ",b)
# Out:
# Masukkan jumlah bab = 3
# Masukkan jumlah sub bab di setiap bab = 5
# 1 .
#     1  .  1
#     1  .  2
#     1  .  3
#     1  .  4
#     1  .  5
# 2 .
#     2  .  1
#     2  .  2
#     2  .  3
#     2  .  4
#     2  .  5
# 3 .
#     3  .  1
#     3  .  2
#     3  .  3
#     3  .  4
#     3  .  5

# %% [markdown]
# ##### 2.4	Menu
# Buatlah code untuk membuat menu, dimana setiap menu melakukan operasi yang berbeda : Menu :
# •	Tekan 1 untuk operasi perhitungan luas lingkaran (input adalah jari-jari)
# •	Tekan 2 untuk operasi perhitungan luas persegi panjang (input adalah panjang dan lebar)
# •	Tekan 3 untuk operasi perhitungan luas segitiga (input adalah alas dan tinggi)

# %%
stop=False
while not(stop):
    print(77*"=",'''
Menu
Tekan 1 untuk operasi perhitungan luas lingkaran (input adalah jari-jari)
Tekan 2 untuk operasi perhitungan luas persegi panjang (input adalah panjang dan lebar)
Tekan 3 untuk operasi perhitungan luas segitiga (input adalah alas adan tinggi)''')
    inp=int(input("masukkan pilihan anda = "))
    if inp==1:
        r=int(input("masukkan jari-jari ="))
        print("Luas lingkaran = ",(22/7)*r**2)
    elif inp==2:
        p=int(input("masukkan panjang = "))
        l=int(input("masukkan lebar = "))
        print("Luas persegi panjang = ",p*l)
    else:
        a=int(input("masukkan alas = "))
        t=int(input("masukkan tinggi = "))
        print("Luas segitiga = ",(1/2)*a*t)
    pilih=input("Ingin menggulangi operasi kembali (y/t) ?")
    if pilih=="t":
        stop=True
# Out:
# ...
# Menu
# Tekan 1 untuk operasi perhitungan luas lingkaran (input adalah jari-jari)
# Tekan 2 untuk operasi perhitungan luas persegi panjang (input adalah panjang dan lebar)
# Tekan 3 untuk operasi perhitungan luas segitiga (input adalah alas adan tinggi)
# masukkan pilihan anda = 2
# masukkan panjang = 5
# masukkan lebar = 1
# Luas persegi panjang =  5
# Ingin menggulangi operasi kembali (y/t) ?y
# ...
# Menu
# Tekan 1 untuk operasi perhitungan luas lingkaran (input adalah jari-jari)
# Tekan 2 untuk operasi perhitungan luas persegi panjang (input adalah panjang dan lebar)
# Tekan 3 untuk operasi perhitungan luas segitiga (input adalah alas adan tinggi)
# masukkan pilihan anda = 3
# masukkan alas = 9
# masukkan tinggi = 11
# Luas segitiga =  49.5
# Ingin menggulangi operasi kembali (y/t) ?t
